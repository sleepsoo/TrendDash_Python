# %% [markdown]
# ## 7가지 감정 데이터

# %%
import pandas as pd

df_exel = pd.read_excel("../dataset_raw/한국어_단발성_대화_데이터셋.xlsx")
emotions = ['행복', '분노', '혐오', '중립']
df_exel = df_exel[df_exel['Emotion'].isin(emotions)]
df_exel.columns = ['내용', 'label']
df_exel = df_exel[['label', '내용']]
df_exel
# Out:
#       label                                                 내용
# 11366    분노                        서해 수자원도 한류라서 그동안 불법조업 방치했나?
# 11367    분노                                           니가 인간이가.
# 11368    분노                          강아지를 때리고 유기하는것만 학대는 아닙니다!
# 11369    분노                              하여간 우리나라 교육엔 미래가 없어!!
# 11370    분노                           채널에이 군부 개인거 인증하냐 동아일보야!!
# ...     ...                                                ...
# 38589    혐오               솔직히 예보 제대로 못하는 데 세금이라도 아끼게 그냥 폐지해라..
# 38590    혐오                                        재미가 없으니 망하지
# 38591    혐오  공장 도시락 비우생적임 아르바이트했는데 화장실가성 손도 않씯고 재료 담고 바닥 떨어...
# 38592    혐오               코딱지 만한 나라에서 지들끼리 피터지게 싸우는 센징 클래스 ㅉㅉㅉ
# 38593    혐오               와이프도 그렇고 댓글 다 볼텐데 이휘재 좀 하차 하라고 전해주세요
#
# [21961 rows x 2 columns]

# %%
label_map = {'행복':'긍정', '분노':'부정', '혐오':'부정'}
df_exel['label'] = df_exel['label'].map(label_map).fillna(df_exel['label'])
df_exel
# Out:
#       label                                                 내용
# 11366    부정                        서해 수자원도 한류라서 그동안 불법조업 방치했나?
# 11367    부정                                           니가 인간이가.
# 11368    부정                          강아지를 때리고 유기하는것만 학대는 아닙니다!
# 11369    부정                              하여간 우리나라 교육엔 미래가 없어!!
# 11370    부정                           채널에이 군부 개인거 인증하냐 동아일보야!!
# ...     ...                                                ...
# 38589    부정               솔직히 예보 제대로 못하는 데 세금이라도 아끼게 그냥 폐지해라..
# 38590    부정                                        재미가 없으니 망하지
# 38591    부정  공장 도시락 비우생적임 아르바이트했는데 화장실가성 손도 않씯고 재료 담고 바닥 떨어...
# 38592    부정               코딱지 만한 나라에서 지들끼리 피터지게 싸우는 센징 클래스 ㅉㅉㅉ
# 38593    부정               와이프도 그렇고 댓글 다 볼텐데 이휘재 좀 하차 하라고 전해주세요
#
# [21961 rows x 2 columns]

# %%
df_exel.to_csv()
# Out:
# ',label,내용\n11366,부정,서해 수자원도 한류라서 그동안 불법조업 방치했나?\n11367,부정, 니가 인간이가.\n11368,부정,강아지를 때리고 유기하는것만 학대는 아닙니다!\n11369,부정,하여간 우리나라 교육엔 미래가 없어!!\n11370,부정,채널에이 군부 개인거 인증하냐 동아일보야!!\n11371,부정, 비싼 요금들 다 어디로 처먹는지들 ㅉㅉ\n11372,부정,김기춘이랑 우병우 이색히들은 공개처형시키고싶다\n11373,부정,닭년이 조언 구했다고 했는데 먼개소리냐\n11374,부정, 자백 안 해도 그동안 나온 증거만으로도 무기징역감이다!\n11375,부정,"청와대는 압수대상안됨,,,"\n11376,부정, 야 맹구들아 자그만치 천억이다\n11377,부정,다 조사해봐라롯데호텔 씨씨티비확인해봐라\n11378,부정,그게 대통령의 할일 아닌가?\n11379,부정,도대체얼마를쳐먹으면저렇게자연스럽게말할수있는거냐?\n11380,부정, 특검은 가혹하게 다스려라\n11381,부정,조윤선이야말로 박근혜 최순실 국정농단의 부역자야 그동안 호가호위해서 좋디?\n11382,부정,할수있는못땐짓은 다했구나~\n11383,부정,드러운 좃선tv 기사내용이네..\n11384,부정, 이런 뉴스 쓰지마라 공무원들 국민혈세 나랏돈 빼먹을 핑계만준다\n11385,부정, 걍 환불이라고해야지!!\n11386,부정,위증하면 너도 300여명 아이들을 죽인 살인자다.\n11387,부정,일본... 절대 잊지 않겠다!!\n11388,부정,이건 대통령이 아니라 도둑년이구만.\n11389,부정,미국에선 원 플러스 원도 하면서!!\n11390,부정, 저런 인간들이 후보라니...\n11391,부정,둘다 나쁜 인간들인데 패륜아집단이 더 더러운새끼들이지\n11392,부정,무슬림 극단주의는 암덩어리 같은 존재\n11393,부정, 나라를 좀먹는 일베충들이다.\n11394,부정, 대가리에 우동사리들었냐.\n11395,부정,교도소장 어떻게 좀 해야 합니다.\n11396,부정, 니가 죽인거야!\n11397,부
# ...

# %% [markdown]
# ## 네이버 평점 데이터

# %%
df_txt = pd.read_csv("../dataset_raw/naver_shopping.txt", sep='\t', header=None, names = ['label', '내용'])
df_txt
# Out:
#         label                                                 내용
# 0           5                                            배공빠르고 굿
# 1           2                      택배가 엉망이네용 저희집 밑에층에 말도없이 놔두고가고
# 2           5  아주좋아요 바지 정말 좋아서2개 더 구매했어요 이가격에 대박입니다. 바느질이 조금 ...
# 3           2  선물용으로 빨리 받아서 전달했어야 하는 상품이었는데 머그컵만 와서 당황했습니다. 전...
# 4           5                  민트색상 예뻐요. 옆 손잡이는 거는 용도로도 사용되네요 ㅎㅎ
# ...       ...                                                ...
# 199995      2                                    장마라그런가!!! 달지않아요
# 199996      5  다이슨 케이스 구매했어요 다이슨 슈퍼소닉 드라이기 케이스 구매했어요가격 괜찮고 배송...
# 199997      5                    로드샾에서 사는것보다 세배 저렴하네요 ㅜㅜ 자주이용할께요
# 199998      5                                      넘이쁘고 쎄련되보이네요~
# 199999      5   아직 사용해보지도않았고 다른 제품을 써본적이없어서 잘 모르겠지만 ㅎㅎ 배송은 빨랐습니다
#
# [200000 rows x 2 columns]

# %%
label_map = {1:"부정", 2:"부정", 4:"긍정", 5:"긍정"}
df_txt['label'] = df_txt["label"].map(label_map).fillna(df_txt['label'])
df_txt
# Out:
#        label                                                 내용
# 0         긍정                                            배공빠르고 굿
# 1         부정                      택배가 엉망이네용 저희집 밑에층에 말도없이 놔두고가고
# 2         긍정  아주좋아요 바지 정말 좋아서2개 더 구매했어요 이가격에 대박입니다. 바느질이 조금 ...
# 3         부정  선물용으로 빨리 받아서 전달했어야 하는 상품이었는데 머그컵만 와서 당황했습니다. 전...
# 4         긍정                  민트색상 예뻐요. 옆 손잡이는 거는 용도로도 사용되네요 ㅎㅎ
# ...      ...                                                ...
# 199995    부정                                    장마라그런가!!! 달지않아요
# 199996    긍정  다이슨 케이스 구매했어요 다이슨 슈퍼소닉 드라이기 케이스 구매했어요가격 괜찮고 배송...
# 199997    긍정                    로드샾에서 사는것보다 세배 저렴하네요 ㅜㅜ 자주이용할께요
# 199998    긍정                                      넘이쁘고 쎄련되보이네요~
# 199999    긍정   아직 사용해보지도않았고 다른 제품을 써본적이없어서 잘 모르겠지만 ㅎㅎ 배송은 빨랐습니다
#
# [200000 rows x 2 columns]

# %% [markdown]
# ## steam 리뷰 데이터

# %%
df_txt2 = pd.read_csv("../dataset_raw/steam.txt", sep='\t', header=None, names = ['label', '내용'])
df_txt2
# Out:
#        label                                                 내용
# 0          0                                          노래가 너무 적음
# 1          0                    돌겠네 진짜. 황숙아, 어크 공장 그만 돌려라. 죽는다.
# 2          1                   막노동 체험판 막노동 하는사람인데 장비를 내가 사야돼 뭐지
# 3          1               차악!차악!!차악!!! 정말 이래서 왕국을 되찾을 수 있는거야??
# 4          1                시간 때우기에 좋음.. 도전과제는 50시간이면 다 깰 수 있어요
# ...      ...                                                ...
# 99995      0                                       한글화해주면 10개산다
# 99996      0                                            개쌉노잼 ㅋㅋ
# 99997      0                             노잼이네요... 30분하고 지웠어요...
# 99998      1  야생을 사랑하는 사람들을 위한 짧지만 여운이 남는 이야기. 영어는 그리 어렵지 않습니다.
# 99999      1                     한국의 메탈레이지를 떠오르게한다 진짜 손맛으로 하는게임
#
# [100000 rows x 2 columns]

# %%
label_map = {0:"부정", 1:"긍정"}
df_txt2['label'] = df_txt2['label'].map(label_map).fillna(df_txt2['label'])
df_txt2
# Out:
#       label                                                 내용
# 0        부정                                          노래가 너무 적음
# 1        부정                    돌겠네 진짜. 황숙아, 어크 공장 그만 돌려라. 죽는다.
# 2        긍정                   막노동 체험판 막노동 하는사람인데 장비를 내가 사야돼 뭐지
# 3        긍정               차악!차악!!차악!!! 정말 이래서 왕국을 되찾을 수 있는거야??
# 4        긍정                시간 때우기에 좋음.. 도전과제는 50시간이면 다 깰 수 있어요
# ...     ...                                                ...
# 99995    부정                                       한글화해주면 10개산다
# 99996    부정                                            개쌉노잼 ㅋㅋ
# 99997    부정                             노잼이네요... 30분하고 지웠어요...
# 99998    긍정  야생을 사랑하는 사람들을 위한 짧지만 여운이 남는 이야기. 영어는 그리 어렵지 않습니다.
# 99999    긍정                     한국의 메탈레이지를 떠오르게한다 진짜 손맛으로 하는게임
#
# [100000 rows x 2 columns]

# %% [markdown]
# ## 내용 합치기

# %%
df_concat = pd.concat([df_txt,df_txt2, df_exel], axis=0)
df_concat
# Out:
#       label                                                 내용
# 0        긍정                                            배공빠르고 굿
# 1        부정                      택배가 엉망이네용 저희집 밑에층에 말도없이 놔두고가고
# 2        긍정  아주좋아요 바지 정말 좋아서2개 더 구매했어요 이가격에 대박입니다. 바느질이 조금 ...
# 3        부정  선물용으로 빨리 받아서 전달했어야 하는 상품이었는데 머그컵만 와서 당황했습니다. 전...
# 4        긍정                  민트색상 예뻐요. 옆 손잡이는 거는 용도로도 사용되네요 ㅎㅎ
# ...     ...                                                ...
# 38589    부정               솔직히 예보 제대로 못하는 데 세금이라도 아끼게 그냥 폐지해라..
# 38590    부정                                        재미가 없으니 망하지
# 38591    부정  공장 도시락 비우생적임 아르바이트했는데 화장실가성 손도 않씯고 재료 담고 바닥 떨어...
# 38592    부정               코딱지 만한 나라에서 지들끼리 피터지게 싸우는 센징 클래스 ㅉㅉㅉ
# 38593    부정               와이프도 그렇고 댓글 다 볼텐데 이휘재 좀 하차 하라고 전해주세요
#
# [321961 rows x 2 columns]

# %%
df_concat.to_csv('review_txt', sep='\t', index=False, encoding='utf-8')

# %%
print(df_concat[df_concat['label']=='긍정'])
print(df_concat[df_concat['label']=='부정'])
print(df_concat[df_concat['label']=='중립'])
# Out:
#       label                                                 내용
# 0        긍정                                            배공빠르고 굿
# 2        긍정  아주좋아요 바지 정말 좋아서2개 더 구매했어요 이가격에 대박입니다. 바느질이 조금 ...
# 4        긍정                  민트색상 예뻐요. 옆 손잡이는 거는 용도로도 사용되네요 ㅎㅎ
# 10       긍정                              사이즈도 딱이고 귀엽고 넘 좋아요 ㅎㅎ
# 14       긍정                               촉감도 좋고 무게감이나 핏도 편합니다
# ...     ...                                                ...
# 33160    긍정                             유느님 내일 이면 해피투게더가하네요~^^
# 33161    긍정                            승관아~ 너에게 편지를 안 쓸 수가 없네.
# 33162    긍정                        패떴 개그계 큰 대모 이경실 씨 1탄 잘 봤습니다
# 33163    긍정                         유재석 오라버니 해피투게더 해피파출소 편 봤어요
# 33164    긍정                                 유재석 오라버니 해피투게더 봤어요
#
# [155996 rows x 2 columns]
#       label                                                 내용
# 1        부정                      택배가 엉망이네용 저희집 밑에층에 말도없이 놔두고가고
# ...
